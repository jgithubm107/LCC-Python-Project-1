# %%
#inporting and naming the file DF
import pandas as pd
project1 = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv ')

# %%
# list the columns
project1.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
# Reading the type of values
project1[['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
       'Total Tested', 'Mean Score', 'Number Scoring Below 65',
       'Percent Scoring Below 65', 'Number Scoring 65 or Above',
       'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
       'Percent Scoring 80 or Above', 'Number Scoring CR',
       'Percent Scoring CR']]
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
project1=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv ')

# %%
# Reading for type of values
project1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
# Finding Null values, regents exam has 10. The NAs was not picked up
project1.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
# Finding Null, na, n/a, and nan values
missing_values = ["n/a", "na"]
project1 = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values=missing_values)
project1.isnull().sum()
# Out:
# School DBN                          0
# School Name                         0
# School Level                        0
# Regents Exam                       10
# Year                                0
# Total Tested                        0
# Mean Score                          0
# Number Scoring Below 65             0
# Percent Scoring Below 65            0
# Number Scoring 65 or Above          0
# Percent Scoring 65 or Above         0
# Number Scoring 80 or Above          0
# Percent Scoring 80 or Above         0
# Number Scoring CR              142680
# Percent Scoring CR             142680
# dtype: int64

# %%
project1.isnull().any()
# Out:
# School DBN                     False
# School Name                    False
# School Level                   False
# Regents Exam                    True
# Year                           False
# Total Tested                   False
# Mean Score                     False
# Number Scoring Below 65        False
# Percent Scoring Below 65       False
# Number Scoring 65 or Above     False
# Percent Scoring 65 or Above    False
# Number Scoring 80 or Above     False
# Percent Scoring 80 or Above    False
# Number Scoring CR               True
# Percent Scoring CR              True
# dtype: bool

# %%
# grouping/counting the # of time a school appear with certain values
groupby_school = project1.groupby('School Name').nunique()
print(groupby_school)
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar           1             1
# A. Philip Randolph Campus High School                        1             1
# ACORN Community High School                                  1             1
# Abraham Lincoln High School                                  1             1
# Abraham Lincoln Yabc                                         1             1
# ...                                                        ...           ...
# Young Women's Leadership School                              1             1
# Young Women's Leadership School of Brooklyn                  1             1
# Young Women's Leadership School of the Bronx                 1             1
# Young Women's Leadership School, Astoria                     1             1
# Young Women's Leadership School, Queens                      1             1
#
# ...

# %%
# grouping/counting the # of time a school appear
groupby_school = project1.groupby('School Name').size()
print(groupby_school)
# Out:
# School Name
# 47 The American Sign Language and English Secondar    356
# A. Philip Randolph Campus High School                 459
# ACORN Community High School                           364
# Abraham Lincoln High School                           480
# Abraham Lincoln Yabc                                  248
#                                                      ...
# Young Women's Leadership School                       378
# Young Women's Leadership School of Brooklyn           337
# Young Women's Leadership School of the Bronx          142
# Young Women's Leadership School, Astoria              338
# Young Women's Leadership School, Queens               391
# Length: 1012, dtype: int64

# %%
import pandas as pd
project1 = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv ')

# %%
import pandas as pd
Project1_No_na = pd.read_csv('/Project 1_updated with NA values.csv')
# Out:
# <ipython-input-5-ea3f94b58b49>:2: DtypeWarning: Columns (6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   Project1_No_na = pd.read_csv('/Project 1_updated with NA values.csv')

# %%
Project1_No_na
# Out:
#        nachool DBN                      nachool Name nachool Level  \
# 0           01M034  P.na. 034 Franklin D. Roonaevelt           K-8
# 1           01M140         P.na. 140 Nathan natrauna           K-8
# 2           01M140         P.na. 140 Nathan natrauna           K-8
# 3           01M188     P.na. 188 The Inaland nachool           K-8
# 4           01M188     P.na. 188 The Inaland nachool           K-8
# ...            ...                               ...           ...
# 212327      84X706    Harriet Tubman Charter nachool           K-8
# 212328      84X717             Icahn Charter nachool           K-8
# 212329      84X717             Icahn Charter nachool           K-8
# 212330      84X717             Icahn Charter nachool           K-8
# 212331      84X717             Icahn Charter nachool           K-8
#
#                Regentna Exam    Year  Total Tenated Mean nacore  \
# 0        Common Core Algebra  2017.0            4.0          na
# ...

# %%
# drop rows up to 142681 with NA in any column
Project1_No_na = Project1_No_na.iloc[142681:]

# %%
# Displaying the table with no NA
# I prepared the file in excel to make it easier to drop a range of rows
Project1_No_na
# Out:
#        nachool DBN                    nachool Name nachool Level  \
# 142681      01M184          P.na. 184m nahuang Wen           K-8
# 142682      01M184          P.na. 184m nahuang Wen           K-8
# 142683      01M184          P.na. 184m nahuang Wen           K-8
# 142684      01M188   P.na. 188 The Inaland nachool           K-8
# 142685      01M188   P.na. 188 The Inaland nachool           K-8
# ...            ...                             ...           ...
# 212327      84X706  Harriet Tubman Charter nachool           K-8
# 212328      84X717           Icahn Charter nachool           K-8
# 212329      84X717           Icahn Charter nachool           K-8
# 212330      84X717           Icahn Charter nachool           K-8
# 212331      84X717           Icahn Charter nachool           K-8
#
#               Regentna Exam    Year  Total Tenated Mean nacore  \
# 142681  Common Core Algebra  2015.0           49.0        78.4
# ...

# %%
# Crearting a subset
Project2 = Project1_No_na[['nachool DBN', 'nachool Name', 'nachool Level', 'Regentna Exam', 'Year', 'Total Tenated', 'Mean nacore']]

# %%
Project2
# Out:
#        nachool DBN                    nachool Name nachool Level  \
# 142681      01M184          P.na. 184m nahuang Wen           K-8
# 142682      01M184          P.na. 184m nahuang Wen           K-8
# 142683      01M184          P.na. 184m nahuang Wen           K-8
# 142684      01M188   P.na. 188 The Inaland nachool           K-8
# 142685      01M188   P.na. 188 The Inaland nachool           K-8
# ...            ...                             ...           ...
# 212327      84X706  Harriet Tubman Charter nachool           K-8
# 212328      84X717           Icahn Charter nachool           K-8
# 212329      84X717           Icahn Charter nachool           K-8
# 212330      84X717           Icahn Charter nachool           K-8
# 212331      84X717           Icahn Charter nachool           K-8
#
#               Regentna Exam    Year  Total Tenated Mean nacore
# 142681  Common Core Algebra  2015.0           49.0        78.4
# ...

# %%
# The 2 school I chose to compare the Mean Nascore in 2015 for Intergrated algebra
Project2 [(Project2 ['nachool Name'] == 'International Artna Bunainenana nachool') | (Project2 ['nachool Name'] == 'Legacy nachool for Integrated natudiena')]
# Out:
#        nachool DBN                             nachool Name nachool Level  \
# 143328      02M429  Legacy nachool for Integrated natudiena  High nachool
# 147799      17K544  International Artna Bunainenana nachool  High nachool
#
#              Regentna Exam    Year  Total Tenated Mean nacore
# 143328  Integrated Algebra  2015.0            7.0        66.0
# 147799  Integrated Algebra  2015.0            8.0        74.6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Project2.plot(kind='line')
# Out:
# <Axes: >
