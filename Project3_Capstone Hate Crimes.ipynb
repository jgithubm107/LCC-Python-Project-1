# %%
# I'm using a Hate crime data set from the FBI date base.
# I want to see if the number of hate crimes increase from  before Trump became President to

# %%
import pandas as pd
US_Hate_Crimes = pd.read_csv('/home/hate_crime.csv')
US_Hate_Crimes
# Out:
#         incident_id  data_year        ori        pug_agency_name  \
# 0                43       1991  AR0350100             Pine Bluff
# 1                44       1991  AR0350100             Pine Bluff
# 2                45       1991  AR0600300      North Little Rock
# 3                46       1991  AR0600300      North Little Rock
# 4                47       1991  AR0670000                 Sevier
# ...             ...        ...        ...                    ...
# 241658      1473449       2022  WY0190200           Rock Springs
# 241659      1473450       2022  WY0010200  University of Wyoming
# 241660      1476554       2022  WY0190000             Sweetwater
# 241661      1476555       2022  WY0110100               Cheyenne
# 241662      1479088       2022  WY0190100            Green River
#
#        pub_agency_unit       agency_type_name state_abbr state_name  \
# 0                  NaN                   City         AR   Arkansas
# ...

# %%
# list the columns
US_Hate_Crimes.columns
# Out:
# Index(['incident_id', 'data_year', 'ori', 'pug_agency_name', 'pub_agency_unit',
#        'agency_type_name', 'state_abbr', 'state_name', 'division_name',
#        'region_name', 'population_group_code', 'population_group_description',
#        'incident_date', 'adult_victim_count', 'juvenile_victim_count',
#        'total_offender_count', 'adult_offender_count',
#        'juvenile_offender_count', 'offender_race', 'offender_ethnicity',
#        'victim_count', 'offense_name', 'total_individual_victims',
#        'location_name', 'bias_desc', 'victim_types', 'multiple_offense',
#        'multiple_bias'],
#       dtype='object')

# %%
# Checking for null/missing values. I'm not interested in those vaulue, so no need to removed them
US_Hate_Crimes.isnull().sum()
# Out:
# incident_id                          0
# data_year                            0
# ori                                  0
# pug_agency_name                      0
# pub_agency_unit                 234474
# agency_type_name                     0
# state_abbr                           0
# state_name                           0
# division_name                        0
# region_name                          0
# population_group_code              555
# population_group_description       555
# incident_date                        0
# adult_victim_count              170538
# juvenile_victim_count           172978
# total_offender_count                 0
# adult_offender_count            177148
# juvenile_offender_count         177155
# offender_race                        0
# offender_ethnicity                   0
# victim_count                         0
# offense_name                         0
# total_individual_victims          4859
# location_name                        0
# ...

# %%
# Created a list of years I want to view called years
years = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
# Created a list of years I want to view called years
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
incident_count = US_Hate_Crimes.groupby('data_year').size()
incident_count
# Out:
# data_year
# 1991     4589
# 1992     6662
# 1993     7604
# 1994     5953
# 1995     7949
# 1996     8789
# 1997     8105
# 1998     7889
# 1999     7940
# 2000     8217
# 2001     9730
# 2002     7485
# 2003     7539
# 2004     7684
# 2005     7411
# 2006     7715
# 2007     7623
# 2008     8039
# 2009     6612
# 2010     6628
# 2011     6299
# 2012     6592
# 2013     6044
# 2014     5597
# 2015     5843
# 2016     6270
# 2017     7327
# 2018     7179
# 2019     7868
# 2020     9949
# 2021    10889
# 2022    11643
# dtype: int64

# %%
offenses_per_year = US_Hate_Crimes.groupby('data_year')['offense_name'].count()
print(offenses_per_year)
# Out:
# data_year
# 1991     4589
# 1992     6662
# 1993     7604
# 1994     5953
# 1995     7949
# 1996     8789
# 1997     8105
# 1998     7889
# 1999     7940
# 2000     8217
# 2001     9730
# 2002     7485
# 2003     7539
# 2004     7684
# 2005     7411
# 2006     7715
# 2007     7623
# 2008     8039
# 2009     6612
# 2010     6628
# 2011     6299
# 2012     6592
# 2013     6044
# 2014     5597
# 2015     5843
# 2016     6270
# 2017     7327
# 2018     7179
# 2019     7868
# 2020     9949
# 2021    10889
# 2022    11643
# Name: offense_name, dtype: int64

# %%
# bar chart showing hate crimes rose after trump took office in 2016
start_date = '1991'
end_date = '2024'

# # Ensure the 'incident_date' column is in datetime format
US_Hate_Crimes['incident_date'] = pd.to_datetime(US_Hate_Crimes['incident_date'], errors='coerce')

# Drop rows with invalid 'incident_date'
US_Hate_Crimes = US_Hate_Crimes.dropna(subset=['incident_date'])

# Extract the year from the 'incident_date' column
US_Hate_Crimes['year'] = US_Hate_Crimes['incident_date'].dt.year

# Filter the data for years between 1991 and 2024
filtered_data = US_Hate_Crimes[(US_Hate_Crimes['year'] >= 1991) & (US_Hate_Crimes['year'] <= 2024)]

# Count the number of incidents per year
incident_counts_per_year = filtered_data['year'].value_counts().sort_index()

# Ensure all years from 1991 to 2024 are included, even if there are no incidents
all_years = pd.Series(0, index=range(1991, 2025))
incident_counts_per_year = incident_counts_per_year.add(all_years, fill_value=0).sort_index()

# Create a bar chart
plt.figure(figsize=(12, 6))
incident_counts_per_year.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.title('Total Number of Hate Crime Incidents Per Year (1991-2024)')
plt.grid(axis='y')
plt.show()

# %%
# line chart showing hate crimes rose after trump took office in 2016
import matplotlib.pyplot as plt

# %%
start_date = 1991
end_date = 2024
mask = (US_Hate_Crimes['data_year'] >= start_date) & (US_Hate_Crimes['data_year'] <= end_date)
filtered_US_Hate_Crimes = US_Hate_Crimes[mask]
# The 'data_year' column is likely already an integer representing the year
# So, we can directly assign it to the 'year' column
filtered_US_Hate_Crimes['year'] = filtered_US_Hate_Crimes['data_year']
offenses_per_year = filtered_US_Hate_Crimes.groupby('year')['offense_name'].count()
years = pd.Series(range(int(start_date), int(end_date) + 1))
offenses_per_year = offenses_per_year.reindex(years, fill_value=0)
plt.figure(figsize=(10, 6))
incident_count.plot(kind='line', color='skyblue')
plt.title('Number of Incidents per Year (1991-2024)', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Incidents', fontsize=14)
plt.xticks(rotation=10)  # Rotate x labels for better readability
plt.grid(axis='y')

plt.show()

# %%
plt.figure(figsize=(18, 6))
offenses_per_year.plot(kind='line', color='skyblue')
plt.title('Number of Offenses Per Year (1991-2024)')
plt.xlabel('Year')
plt.ylabel('Number of Offenses')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show('incident_date')

# %%
# Import the matplotlib library
import matplotlib.pyplot as plt

# bar chart showing hate crimes rose after trump took office in 2016
start_date = '1991'
end_date = '2022'

# # Ensure the 'incident_date' column is in datetime format
US_Hate_Crimes['incident_date'] = pd.to_datetime(US_Hate_Crimes['incident_date'], errors='coerce')

# Drop rows with invalid 'incident_date'
US_Hate_Crimes = US_Hate_Crimes.dropna(subset=['incident_date'])

# Extract the year from the 'incident_date' column
US_Hate_Crimes['year'] = US_Hate_Crimes['incident_date'].dt.year

# Filter the data for years between 1991 and 2024
filtered_data = US_Hate_Crimes[(US_Hate_Crimes['year'] >= 1991) & (US_Hate_Crimes['year'] <= 2022)]

# Count the number of incidents per year
incident_counts_per_year = filtered_data['year'].value_counts().sort_index()

# Ensure all years from 1991 to 2024 are included, even if there are no incidents
all_years = pd.Series(0, index=range(1991, 2022))
incident_counts_per_year = incident_counts_per_year.add(all_years, fill_value=0).sort_index()

# Create a bar chart
plt.figure(figsize=(12, 6)) # Now plt is defined and can be used
incident_counts_per_year.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.title('Total Number of Hate Crime Incidents Per Year (1991-2022)')
plt.grid(axis='y')
plt.show()
